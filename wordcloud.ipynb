# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('all_cipdata9.6x.dsv',sep='|',usecols=['NAM','FRST_NAM','LST_NAM','TYP_CDE'])

# %%
datap = data.loc[data['TYP_CDE']=='PERSON']
datap=datap[datap.NAM.notnull()]
datao = data.loc[data['TYP_CDE']=='ORGANIZATION']
datao=datao[datao.NAM.notnull()]
datap.head()
# Out:
#       TYP_CDE                        NAM   FRST_NAM           LST_NAM
# 17125  PERSON              Claus Aagaard      Claus           Aagaard
# 17126  PERSON    Birgit Aagaard-Svendsen     Birgit  Aagaard-Svendsen
# 17127  PERSON          Brady Gordon Aase      Brady              Aase
# 17128  PERSON  Maria Paz Abarca Orellana  Maria Paz   Abarca Orellana
# 17129  PERSON                James Abate      James             Abate

# %%
pnam = ' '.join(datap['NAM'])
onam = ' '.join(datao['NAM'])

stopwords = set(STOPWORDS)
stopwords.update(["DE", "JR","SR","II","III"])

wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    collocations=False,
    stopwords = stopwords).generate(str(pnam))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud.to_file("wordcloudnames3.png")

# %%
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    collocations=False,
    stopwords = stopwords).generate(str(onam))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
datap['NAM'].value_counts()
# Out:
# Paul Oberkotter                  46
# Frank C. Mars                    34
# Kevin M Curran                   24
# Louise M Oberkotter              23
# Nicole M Bronenkamp              18
#                                  ..
# Lisa D. Van Gilder                1
# Hong-Chen Lin                     1
# Kathy J. Nicolette                1
# Charles Edmund Philip Plowden     1
# Oliver J. Greenwald               1
# Name: NAM, Length: 13086, dtype: int64

# %%
datao['NAM'].value_counts()
# Out:
# State of Delaware                   70
# Brown Brothers Harriman             56
# Bain Capital, LP                    38
# Brown Brothers Harriman & Co.       35
# Aramark Corporation                 24
#                                     ..
# TIMOTHY J. RUSSERT FAMILY TRUST      1
# Fresco Fabrics, LLC                  1
# JULES TOLL BUCKNER 2503(C) TRUST     1
# Shannon Outley Trust No. 1           1
# Atlantic Roofing Corproation         1
# Name: NAM, Length: 13539, dtype: int64
